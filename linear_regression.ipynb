# %% [markdown]
# # Lê Hoàng Thịnh
# ### MSSV - 19520285
# Sử dụng mô hình linear regression để dự đoán mức lương dựa trên số năm kinh nghiệm

# %% [markdown]
# Import libraries

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Read data

# %%
data=pd.read_csv('/content/Salary_Data.csv')
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# Instantiate linear regression model

# %%
model= LinearRegression()

# %% [markdown]
# Extract data

# %%
X = data.iloc[:,:-1]
X
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y=data.iloc[:,1:2]
y
# Out:
#       Salary
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# 10   63218.0
# 11   55794.0
# 12   56957.0
# 13   57081.0
# 14   61111.0
# 15   67938.0
# 16   66029.0
# 17   83088.0
# 18   81363.0
# 19   93940.0
# 20   91738.0
# 21   98273.0
# 22  101302.0
# 23  113812.0
# 24  109431.0
# 25  105582.0
# 26  116969.0
# 27  112635.0
# 28  122391.0
# 29  121872.0

# %% [markdown]
# Split dataset in train and testing set

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state =0)

# %% [markdown]
# Train model

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Start Prediction

# %%
y_predicted=model.predict(X_test)
y_predicted
# Out:
# array([[ 40748.96184072],
#        [122699.62295594],
#        [ 64961.65717022],
#        [ 63099.14214487],
#        [115249.56285456],
#        [107799.50275317]])

# %%
import matplotlib.pyplot as plt
# Visualising the Training set results in a scatter plot
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, model.predict(X_train), color = 'blue')
plt.title('Salary (Training set)')
plt.xlabel('Year experiences')
plt.ylabel('Salary')
plt.show()

# Visualising the test set results in a scatter plot
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, model.predict(X_train), color = 'blue')
plt.title('Salary (Test set)')
plt.xlabel('Year experiences')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # Testing model accuracy using r2_score

# %%
from sklearn.metrics import r2_score

score=r2_score(y_test,y_predicted)

print(f'Model accuracy: {score*100}%')
# Out:
# Model accuracy: 98.8169515729126%
